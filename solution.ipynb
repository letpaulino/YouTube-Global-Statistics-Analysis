# %%
from Dataset import Dataset
from Util import read_youtube_data
import analysis as a

df = read_youtube_data(Dataset.YOUTUBE)

a.plot_top_subscribers(df)
a.plot_bottom_subscribers(df)
a.plot_top_views(df)
a.plot_channels_by_category(df)
a.plot_uploads_vs_subscribers(df)
a.plot_channels_by_country(df)
a.plot_channels_by_year(df)

# Interactive map
m = a.plot_earnings_map(df)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_92154e3ad3f2af838533a21f34e70e57 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_92154e3ad3f2af838533a21f34e70e57&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_92154e3ad3f2af838533a21f34e70e57 = L.map(
#                 &quot;map_92154e3ad3f2af838533a21f34e70e57&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 2,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6a8f5cd937c992df68af976adec88cea = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6a8f5cd937c992df68af976adec88cea.addTo(map_92154e3ad3f2af838533a21f34e70e57);
#
#
#             var circle_marker_d5b8638191927119f1def9e719d290d3 = L.circleMarker(
#                 [35.907757, 127.766922],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 32.68, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_92154e3ad3f2af838533a21f34e70e57);
#
#
#         var popup_9f51948aa1efc281584337d52373dae2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8a881b33565deba6db039fb29f232469 = $(`&lt;div id=&quot;html_8a881b33565deba6db039fb29f232469&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ýýýýýýýýý KIMPRO: $163,400,000&lt;/div&gt;`)[0];
#                 popup_9f51948aa1efc281584337d52373dae2.setContent(html_8a881b33565deba6db039fb29f232469);
#
#
#
#         circle_marker_d5b8638191927119f1def9e719d290d3.bindPopup(popup_9f51948aa1efc281584337d52373dae2)
#         ;
#
#
#
#
#             var circle_marker_438e5cd659ab8fb1c454e8336d892845 = L.circleMarker(
#                 [37.09024, -95.712891],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 22.12, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_92154e3ad3f2af838533a21f34e70e57);
#
#
#         var popup_3b120da06a3e5f8263ee430a8c8159bf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cfa1a389471950d5fb77e15ed5d99ca4 = $(`&lt;div id=&quot;html_cfa1a389471950d5fb77e15ed5d99ca4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;DaFuq!?Boom!: $110,600,000&lt;/div&gt;`)[0];
#                 popup_3b120da06a3e5f8263ee430a8c8159bf.setContent(html_cfa1a389471950d5fb77e15ed5d99ca4);
#
#
#
#         circle_marker_438e5cd659ab8fb1c454e8336d892845.bindPopup(popup_3b120da06a3e5f8263ee430a8c8159bf)
#         ;
#
#
#
#
#             var circle_marker_663c92f9475bf15e54dc8aedce8fae71 = L.circleMarker(
#                 [20.593684, 78.96288],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 21.68, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_92154e3ad3f2af838533a21f34e70e57);
#
#
#         var popup_0a5df14b233b04d2b43ad648eaaf9aa4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_48aa2164389ad247d8e38b2aaffbf013 = $(`&lt;div id=&quot;html_48aa2164389ad247d8e38b2aaffbf013&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;T-Series: $108,400,000&lt;/div&gt;`)[0];
#                 popup_0a5df14b233b04d2b43ad648eaaf9aa4.setContent(html_48aa2164389ad247d8e38b2aaffbf013);
#
#
#
#         circle_marker_663c92f9475bf15e54dc8aedce8fae71.bindPopup(popup_0a5df14b233b04d2b43ad648eaaf9aa4)
#         ;
#
#
#
#
#             var circle_marker_2e5d1c63cd2d2cd0b4b94c1e6fad7906 = L.circleMarker(
#                 [37.09024, -95.712891],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;:
